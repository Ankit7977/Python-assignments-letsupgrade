# %%
a=10
b=103
a==b
# Out:
# True

# %%
a=3
b=4
a<=b
# Out:
# True

# %%
a=4
b=6
a>=b
# Out:
# False

# %%
a=6
b=7
a+=b
print(b)
# Out:
# 7

# %%
a=6
a**2
# Out:
# 36

# %%
10%3
# Out:
# 1

# %%
20/3
# Out:
# 6.666666666666667

# %%
20//3
# Out:
# 6

# %%
20>3
# Out:
# True

# %%
20!=4
# Out:
# True

# %%
a=12
b=9
a>33 and b<20
# Out:
# False

# %%
a>20 or b<8
# Out:
# False

# %%
print("hellow \
python")
# Out:
# hellow python

# %%
print("hellow \n python")
# Out:
# hellow
#  python

# %%
id="657"
marks=90
print("the id no is %s and marks is %d"%(id,marks))
# Out:
# the id no is 657 and marks is 90

# %%
print(f"the id no is {id} and marks is {marks}")
# Out:
# the id no is 657 and marks is 90
