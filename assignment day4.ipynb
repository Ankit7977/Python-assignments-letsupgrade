# %%
import re
string1 = "How are you you are you"
substring = "you"
find = re.finditer(substring , string1)
matched_positions = [match.start() for match in find]
print(matched_positions)
# Out:
# [8, 12, 20]

# %%
str1 = "HEllow"
str1.islower()
# Out:
# False

# %%
str = "hellow"
str.islower()
# Out:
# True

# %%
str = "HELLOW"
str.isupper()
# Out:
# True

# %%
str = "Hell#0"
str.isupper()
# Out:
# False

# %%
str = "HELLO#"
str.isupper()
# Out:
# True
